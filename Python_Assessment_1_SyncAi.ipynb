# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhiram-Bhuvanagiri/SyncAi-Python-Assessment-1/blob/main/Python_Assessment_1_SyncAi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
print("hello world")

#2
print("###")

#3
print(1818+9390)

#4
print((1818+9390)-8790)

#5
print(37*61*391)

#6
print(33986 / 176)

#7
print("batman")
print(5)

#8
print("algebra")
print("####")

#9
a, b = input().split()
print(b, a)

#10
text = input()
print("Given input :", text)

#11
word = input()
print("Happy", word)

#12
num = "9008"
print(num[0])
print(num[-1])

#13
num = "69"
print(num[::-1])

#14
text = "submittheassessment"
print(len(text))

#15
print("***")

#16
word = "goop"
print(len(word[1:-1]))

#17
word = "Fusk"

print(word[0] + "*" * (len(word) - 1))

#18
word = input()
print(len(word) / 2)

#19
print("***")
print("* *")
print("***")

#20
print("*")
print("**")
print("***")

#21
word = input()
print("**", word, "**")

#22
A = input()
B = input()
print(B)
print("###")
print(A)

#23
a = input()
b = input()
c = input()
print(a[0] + b[0] + c[0])

#24
W1 = input()
W2 = input()
print(len(W2) - 1)

#25
word = input()
print(word[0])
print(word[-1])

#26
word = input()
print(word[0] + "*" * (len(word) - 2) + word[-1])
# Out:
# hello world
# ###
# 11208
# 2418
# 882487
# 193.10227272727272
# batman
# 5
# algebra
# ####
# book pen
# pen book
# Happy coding
# Given input : Happy coding
# Holi
# Happy Holi
# 9
# 8
# 96
# 19
# ***
# 2
# F***
# zebra
# 2.5
# ***
# * *
# ***
# *
# **
# ***
# Cover drive
# ** Cover drive **
# Cat
# rat
# rat
# ###
# Cat
# Very
# Important
# person
# VIp
# Midterm
# Mid
# 2
# qwerty
# q
# y
# qwerty@2026
# q*********6
